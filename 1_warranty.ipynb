# %%
import pandas as pd

file = r"C:\Users\Renzo\Freelance\Datasets\Ecom 1\1_Warranty Database.xlsx"
sheets = pd.read_excel(file, sheet_name=None)

for sheet_name, df in sheets.items():
    output_path = r"C:\Users\Renzo\Onedrive\Freelance\1_Warranty\\" + sheet_name + ".csv"
    df.to_csv(output_path, index=False)
    print(f"Exported: {sheet_name}.csv")
